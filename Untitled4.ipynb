# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df1=pd.read_csv('/content/drive/MyDrive/C&T train dataset.csv')
dframe=pd.read_csv('/content/drive/MyDrive/C&T test dataset.csv')
df=df=pd.concat([df1,dframe],axis=1)
df
# Out:
#      sno acc_info  duration_month credit_history purpose savings_acc  \
# 0      1      A11               6            A34     A43         A65
# 1      2      A12              48            A32     A43         A61
# 2      3      A14              12            A34     A46         A61
# 3      4      A11              42            A32     A42         A61
# 4      5      A11              24            A33     A40         A61
# ..   ...      ...             ...            ...     ...         ...
# 795  796      A14               9            A32     A42         A62
# 796  797      A11              18            A32     A41         A65
# 797  798      A14              12            A34     A42         A61
# 798  799      A14              24            A33     A40         A65
# 799  800      A12               9            A32     A40         A65
#
#     employment_st  poi personal_status gurantors  ...  resident_since  \
# ...

# %%
df.isna().sum()
# Out:
# sno                   0
# acc_info              0
# duration_month        0
# credit_history        0
# purpose               0
# savings_acc           0
# employment_st         8
# poi                  12
# personal_status       0
# gurantors             8
# resident_since        0
# property_type         0
# age                   4
# installment_type      0
# housing_type          7
# credits_no            0
# job_type              0
# liables               0
# telephone             0
# foreigner             0
# Group_no              0
# sno                 600
# acc_info            600
# duration_month      600
# credit_history      600
# purpose             600
# savings_acc         600
# employment_st       605
# poi                 605
# personal_status     600
# gurantors           600
# resident_since      600
# property_type       600
# age                 602
# installment_type    600
# housing_type        608
# credits_no          600
# job_type            600
# ...

# %%
df.dtypes
# Out:
# sno                   int64
# acc_info             object
# duration_month        int64
# credit_history       object
# purpose              object
# savings_acc          object
# employment_st        object
# poi                 float64
# personal_status      object
# gurantors            object
# resident_since        int64
# property_type        object
# age                 float64
# installment_type     object
# housing_type         object
# credits_no            int64
# job_type             object
# liables               int64
# telephone            object
# foreigner            object
# Group_no              int64
# sno                 float64
# acc_info             object
# duration_month      float64
# credit_history       object
# purpose              object
# savings_acc          object
# employment_st        object
# poi                 float64
# personal_status      object
# gurantors            object
# resident_since      float64
# property_type        object
# ...

# %%
df = df.dropna()
df
# Out:
#      sno acc_info  duration_month credit_history purpose savings_acc  \
# 0      1      A11               6            A34     A43         A65
# 1      2      A12              48            A32     A43         A61
# 2      3      A14              12            A34     A46         A61
# 3      4      A11              42            A32     A42         A61
# 4      5      A11              24            A33     A40         A61
# ..   ...      ...             ...            ...     ...         ...
# 193  194      A14               6            A32     A43         A61
# 194  195      A12              45            A32     A43         A62
# 195  196      A12               9            A34     A46         A61
# 198  199      A12              24            A32     A41         A65
# 199  200      A12              18            A33     A42         A61
#
#     employment_st  poi personal_status gurantors  ...  resident_since  \
# ...

# %%
df.isna().sum()
# Out:
# sno                 0
# acc_info            0
# duration_month      0
# credit_history      0
# purpose             0
# savings_acc         0
# employment_st       0
# poi                 0
# personal_status     0
# gurantors           0
# resident_since      0
# property_type       0
# age                 0
# installment_type    0
# housing_type        0
# credits_no          0
# job_type            0
# liables             0
# telephone           0
# foreigner           0
# Group_no            0
# sno                 0
# acc_info            0
# duration_month      0
# credit_history      0
# purpose             0
# savings_acc         0
# employment_st       0
# poi                 0
# personal_status     0
# gurantors           0
# resident_since      0
# property_type       0
# age                 0
# installment_type    0
# housing_type        0
# credits_no          0
# job_type            0
# liables             0
# telephone           0
# foreigner           0
# dtype: int64

# %%
df.drop(['sno','acc_info','employment_st'],axis=1,inplace=True)
df
# Out:
# <ipython-input-7-9536e571cd6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['sno','acc_info','employment_st'],axis=1,inplace=True)
#      duration_month credit_history purpose savings_acc  poi personal_status  \
# 0                 6            A34     A43         A65  4.0             A93
# 1                48            A32     A43         A61  2.0             A92
# 2                12            A34     A46         A61  2.0             A93
# 3                42            A32     A42         A61  2.0             A93
# 4                24            A33     A40         A61  3.0             A93
# ..              ...            ...     ...         ...  ...             ...
# 193               6            A32     A43         A61  2.0             A94
# ...

# %%
credit_history = df['credit_history'].values

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['purpose'] = le.fit_transform(df['purpose'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-eb384d7b7701> in <cell line: 10>()
#       8
#       9 # Fit and transform the LabelEncoder on the 'purpose' array
# ---> 10 df['purpose_encoded'] = le.fit_transform(purpose)
#      11
#      12 # Print the DataFrame to see the encoded column
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     114             Encoded labels.
#     115         """
# ...
